# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
from routines import *

# %% [markdown]
# # Load the data

# %%
sample = 5
PATH = '/Users/andreykatz/frbs_cernbox/jk/results/'
filename = 'scint-mwism-' + str(sample) + '.summary.dat'

# %%
metadata = read_events_metadata(PATH+filename)
events = {}
for i in range(metadata.shape[0]):
    events[i] = read_event(i, PATH + filename)
# Out:
# /Users/andreykatz/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.73064e-19): result may not be accurate.
#   overwrite_a=True).T
# /Users/andreykatz/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.73064e-19): result may not be accurate.
#   overwrite_a=True).T
# /Users/andreykatz/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.73064e-19): result may not be accurate.
#   overwrite_a=True).T
# /Users/andreykatz/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.73064e-19): result may not be accurate.
#   overwrite_a=True).T

# %% [markdown]
# # See how one event looks

# %%
x1, x2, x3, x4, x5, x6 = plot_event(0, events, metadata, sigma_cut = 1)

# %% [markdown]
# # Analyze the entire set and get the significances

# %%
ms = len(set(metadata.M))
xs = len(set(metadata.x_diff_ism))
significanceP = np.zeros((xs, ms))
significanceS = np.zeros((xs, ms))
significance5 = np.zeros((xs, ms))
significance10 = np.zeros((xs, ms))
significance15 = np.zeros((xs, ms))
distP = np.zeros((xs, ms))
distS = np.zeros((xs, ms))
dist5 = np.zeros((xs, ms))
dist10 = np.zeros((xs, ms))  
dist15 = np.zeros((xs, ms))

# %%
def update_table(dist, sig, d, s, a, b):
    if d > 0.15:
        dist[a, b] = 20
        sig[a, b] = 0
        return dist, sig
    else:
        dist[a, b] = d
        sig[a, b] = s
        return dist, sig

# %%
for i in range(metadata.shape[0]):
    print('Analyzing event number {}'.format(i))
    a, b = i // ms, i % ms 
    s1, d1, s2, d2, sc, dc = plot_event(i, events, metadata, smearing = [5, 10, 15], sigma_cut = 1., 
                                        produce_plot = False, output = False)
    distP, significanceP = update_table(distP, significanceP, d1, s1, a, b)
    distS, significanceS = update_table(distP, significanceS, d2, s2, a, b)
    dist5, significance5 = update_table(dist5, significance5, dc[0], sc[0], a, b)
    dist10, significance10 = update_table(dist10, significance10, dc[1], sc[1], a, b)
    dist15, significance15 = update_table(dist15, significance15, dc[2], sc[2], a, b)
# Out:
# Analyzing event number 0
# Analyzing event number 1
# Analyzing event number 2
# Analyzing event number 3
# Analyzing event number 4
# Analyzing event number 5
# Analyzing event number 6
# Analyzing event number 7
# Analyzing event number 8
# Analyzing event number 9
# Analyzing event number 10
# Analyzing event number 11
# Analyzing event number 12
# Analyzing event number 13
# Analyzing event number 14
# Analyzing event number 15
# Analyzing event number 16
# Analyzing event number 17
# Analyzing event number 18
# Analyzing event number 19

# %% [markdown]
# # Plot the outcome and save the results

# %%
PATH_RESULTS = '/Users/andreykatz/frbs_cernbox/ak/new_sample/'

# %%
masses = list(set(metadata.M))
rdiff = list(set(np.log10(metadata.x_diff_ism)))
masses_lab = [r'${}\, M_\odot$'.format(m) for m in masses]
rdiff_lab = [r'$10^{{{}}}$ cm'.format(int(x)) for x in rdiff]

# %%
def normalize(sig, masses = 5, xs = 4):
    toplot = np.zeros((xs, masses))
    for i in range(masses * xs):
        a, b = i//masses, i%masses
        if sig[a, b] > 5:
            toplot[a, b] = 5
        else:
            toplot[a, b] = sig[a, b]
    return toplot

# %%
fig, ax = plt.subplots(1, 2, figsize = (13, 6))
ax[0].matshow(normalize(significanceP, masses = ms, xs = xs), 
  cmap = 'coolwarm', interpolation = 'gaussian')
ax[0].xaxis.set_ticks_position('bottom')
ax[0].set_xticks(np.arange(len(masses)))
ax[0].set_yticks(np.arange(len(rdiff_lab)))
ax[0].set_ylim([3.5, -.5])
ax[0].set_xticklabels(masses_lab)
ax[0].set_yticklabels(rdiff_lab)
for x in range(ms):
    for y in range(xs):
        ax[0].text(x, y, round(significanceP[y, x], 1), color = 'k', fontsize = 13,
                ha = 'center', va = 'center')
ax[0].set_title('FFT of the power spectrum', fontsize = 17)
########################################################################################
ax[1].matshow(normalize(significanceS, masses = ms, xs = xs), 
  cmap = 'coolwarm', interpolation = 'gaussian')
ax[1].xaxis.set_ticks_position('bottom')
ax[1].set_xticks(np.arange(len(masses_lab)))
ax[1].set_yticks(np.arange(len(rdiff_lab)))
ax[1].set_ylim([3.5, -.5])
ax[1].set_xticklabels(masses)
ax[1].set_yticklabels(rdiff)
for x in range(ms):
    for y in range(xs):
        ax[1].text(x, y, round(significanceS[y, x], 1), color = 'k', fontsize = 13,
                ha = 'center', va = 'center')
ax[1].set_title('Fitted spectrum', fontsize = 17)
plt.savefig(PATH_RESULTS + 'significances_noconv_sample' + str(sample) +'.pdf')

# %% [markdown]
# Finally simply safe the results.

# %%
np.save(PATH_RESULTS + 'sample' + str(sample) + '_power_sigma', significanceP)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_power_distance', distP)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_sub_sigma', significanceS)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_sub_distance', distS)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_conv5_sigma', significance5)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_conv5_distance', dist5)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_conv10_sigma', significance10)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_conv10_distance', dist10)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_conv15_sigma', significance15)
np.save(PATH_RESULTS + 'sample' + str(sample) + '_conv15_distance', dist15)

# %% [markdown]
# Plot an save with the convolution:

# %%
fig, ax = plt.subplots(1, 3, figsize = (18, 6))
ax[0].matshow(normalize(significance5), cmap = 'coolwarm', interpolation = 'gaussian')
ax[0].xaxis.set_ticks_position('bottom')
ax[0].set_xticks(np.arange(len(masses)))
ax[0].set_yticks(np.arange(len(rdiff)))
ax[0].set_ylim([3.5, -.5])
ax[0].set_xticklabels(masses_lab)
ax[0].set_yticklabels(rdiff_lab)
for x in range(ms):
    for y in range(xs):
        ax[0].text(x, y, round(significance5[y, x], 1), color = 'k', fontsize = 13,
                ha = 'center', va = 'center')
ax[0].set_title('Convolution 5-pads', fontsize = 17)
##########################################################
##########################################################
ax[1].matshow(normalize(significance10), cmap = 'coolwarm', interpolation = 'gaussian')
ax[1].xaxis.set_ticks_position('bottom')
ax[1].set_xticks(np.arange(len(masses)))
ax[1].set_yticks(np.arange(len(rdiff)))
ax[1].set_ylim([3.5, -.5])
ax[1].set_xticklabels(masses_lab)
ax[1].set_yticklabels(rdiff_lab)
for x in range(ms):
    for y in range(xs):
        ax[1].text(x, y, round(significance10[y, x], 1), color = 'k', fontsize = 13,
                ha = 'center', va = 'center', weight = 'bold')
ax[1].set_title('Convolution 10-pads', fontsize = 17)
#########################################################
#########################################################
ax[2].matshow(normalize(significance15), cmap = 'coolwarm', interpolation = 'gaussian')
ax[2].xaxis.set_ticks_position('bottom')
ax[2].set_xticks(np.arange(len(masses)))
ax[2].set_yticks(np.arange(len(rdiff)))
ax[2].set_ylim([3.5, -.5])
ax[2].set_xticklabels(masses_lab)
ax[2].set_yticklabels(rdiff_lab)
for x in range(ms):
    for y in range(xs):
        ax[2].text(x, y, round(significance15[y, x], 1), color = 'k', fontsize = 13,
                ha = 'center', va = 'center', weight = 'bold')
ax[2].set_title('Convolutions 15-pads', fontsize = 17)

plt.savefig(PATH_RESULTS + 'significances_conv_sample' + str(sample) + '.pdf')
